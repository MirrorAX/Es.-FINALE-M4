# %%
# TRACCIA
'''Analisi diffusione COVID-19 nel mondo Il committente richiede di 
avere un report su casi e vaccinazioni in diverse aree del mondo; a tal fine,
richiede di utilizzare il dataset, curato da Our World in Data, all'indirizzo
https://github.com/owid/covid-19-data/tree/master/public/data; alla voce "🗂 
Download our complete COVID-19 dataset" scaricare il dataset in formato CSV 
oppure in formato JSON. 
•Si richiede di verificare le dimensioni del dataset e le diciture presenti nell'intestazione;
•Si chiede poi per ogni continente di trovare il numero di casi totali avvenuti in quello stesso continente; 
si chiede di non considerare eventuali locazioni che nel dataset non appartengono ad alcun continente;
•Sempre riguardo i casi di COVID totali, si chiede di sviluppare una funzione che prenda in input il dataset e due nomi di continenti,
e che ne confronti i seguenti relativi descrittori statistici: valori minimo e massimo, media,
e percentuale rispetto al numero dei casi totali nel mondo (calcolati anche sulle locazioni senza indicazione di continente);
•Si chiede poi di effettuare lo stesso tipo di analisi 
– anche in questo caso sviluppando una funzione ad hoc
– per il numero di vaccinazioni totali per ogni continente;
•Alla fine, basandosi sui calcoli fatti, il committente chiede di stilare
un breve (tre o quattro righe) paragrafo testuale riassuntivo sulle statistiche di casi e vaccinazioni, 
che si concentri solo sulle differenze esistenti tra Europa, Sud America e Oceania '''
# Out:
# 'Analisi diffusione COVID-19 nel mondo Il committente richiede di \navere un report su casi e vaccinazioni in diverse aree del mondo; a tal fine,\nrichiede di utilizzare il dataset, curato da Our World in Data, all\'indirizzo\nhttps://github.com/owid/covid-19-data/tree/master/public/data; alla voce "🗂 \nDownload our complete COVID-19 dataset" scaricare il dataset in formato CSV \noppure in formato JSON. \n•Si richiede di verificare le dimensioni del dataset e le diciture presenti nell\'intestazione;\n•Si chiede poi per ogni continente di trovare il numero di casi totali avvenuti in quello stesso continente; \nsi chiede di non considerare eventuali locazioni che nel dataset non appartengono ad alcun continente;\n•Sempre riguardo i casi di COVID totali, si chiede di sviluppare una funzione che prenda in input il dataset e due nomi di continenti,\ne che ne confronti i seguenti relativi descrittori statistici: valori minimo e massimo, media,\ne percentuale rispetto al numero dei casi tot
# ...

# %%
import pandas as pd


file_finale = "owid-covid-data.csv"

es_finale = pd.read_csv(file_finale)

pd.DataFrame(es_finale)
# Out:
# C:\Users\moren\AppData\Local\Temp\ipykernel_12840\2480696721.py:6: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   es_finale = pd.read_csv(file_finale)
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 376962      ZWE    Africa     Zimbabwe  2024-01-31     266265.0        0.0
# 376963      ZWE    Africa     Zimbabwe  2024-02-01     266265.0        0.0
# 376964      ZWE    Africa     Zimbabwe  2024-02-02     266265.0        0.0
# ...

# %%
#1
es_finale.shape
es_finale.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
#2 ho trovato questo metodo, ma non mi soddisfaceva, perchè ripetitivo e macchinoso
europe = es_finale.loc[es_finale["continent"]=="Europe"]
europe_1 = europe.dropna(subset="total_cases")

africa = es_finale.loc[es_finale["continent"]=="Africa"]
africa_1 = africa.dropna(subset="total_cases")

asia = es_finale.loc[es_finale["continent"]=="Asia"]
asia_1 = asia.dropna(subset="total_cases")

nord_america = es_finale.loc[es_finale["continent"]=="North America"]
nord_america_1 = nord_america.dropna(subset="total_cases")

sud_america = es_finale.loc[es_finale["continent"]=="South America"]
sud_america_1 = sud_america.dropna(subset="total_cases")

oceania = es_finale.loc[es_finale["continent"]=="Oceania"]
oceania_1 = oceania.dropna(subset="total_cases")



casi_europa = max(europe_1["total_cases"])
casi_africa = max(africa_1["total_cases"])
casi_asia = max(asia_1["total_cases"])
casi_nord_america = max(nord_america_1["total_cases"])
casi_sud_america = max(sud_america_1["total_cases"])
casi_oceania = max(oceania_1["total_cases"])

print("i casi totali di Covid in Europa sono",casi_europa)
print("i casi totali di Covid in Africa sono",casi_africa)
print("i casi totali di Covid in Asia sono",casi_asia)
print("i casi totali di Covid nel Nord America sono",casi_nord_america)
print("i casi totali di Covid nel Sud America sono",casi_sud_america)
print("i casi totali di Covid in Oceania sono",casi_oceania)
# Out:
# i casi totali di Covid in Europa sono 38997490.0
# i casi totali di Covid in Africa sono 4072636.0
# i casi totali di Covid in Asia sono 99329249.0
# i casi totali di Covid nel Nord America sono 103436829.0
# i casi totali di Covid nel Sud America sono 37519960.0
# i casi totali di Covid in Oceania sono 11769858.0

# %%
#2 ho voluto provare con un ciclo for
zone = ("Europe", "Africa", "Asia", "North America", "South America", "Oceania")
print("Casi per continente:")

for continente in zone:
    continente_df = es_finale.loc[es_finale["continent"] == continente] 
    casi_totali = max(continente_df.dropna(subset="total_cases")["total_cases"])
    print(f"continente: {continente} casi_totali: {casi_totali}")
# Out:
# Casi per continente:
# continente: Europe casi_totali: 38997490.0
# continente: Africa casi_totali: 4072636.0
# continente: Asia casi_totali: 99329249.0
# continente: North America casi_totali: 103436829.0
# continente: South America casi_totali: 37519960.0
# continente: Oceania casi_totali: 11769858.0

# %%
#3
import numpy as np
confronto = ("Europe","Asia")

print("Prendendo in considerazione i valori di Europa ed Asia:")

for tc in confronto:
    casi_europa_asia = es_finale.loc[es_finale["continent"] == tc] 
    massimo = max(casi_europa_asia.dropna(subset="total_cases")["total_cases"])
    minimo = min(casi_europa_asia.dropna(subset="total_cases")["total_cases"])
    media = np.ma.average(casi_europa_asia.dropna(subset="total_cases")["total_cases"])
    percentuale_mondiale = (max(es_finale.dropna(subset="total_cases")["total_cases"]))
    percentuale_ae = (massimo) / (percentuale_mondiale) * 100 

    print(f"per quanto riguarda i casi totali di contagio, il max è {massimo}, il min è {minimo}, la media è {media}")
    print(f"Invece, per quanto riguarda la percentuale di casi totali rispetto al mondo, otteniamo {percentuale_ae}%")
    print("---------------")
# Out:
# Prendendo in considerazione i valori di Europa ed Asia:
# per quanto riguarda i casi totali di contagio, il max è 38997490.0, il min è 1.0, la media è 2602675.778776635
# Invece, per quanto riguarda la percentuale di casi totali rispetto al mondo, otteniamo 5.03522565883945%
# ---------------
# per quanto riguarda i casi totali di contagio, il max è 99329249.0, il min è 1.0, la media è 3079394.3003714457
# Invece, per quanto riguarda la percentuale di casi totali rispetto al mondo, otteniamo 12.825060875406411%
# ---------------

# %%
#4
zone = ("Europe", "Africa", "Asia", "North America", "South America", "Oceania")
print("Casi per ogni continente in ordine: Europa, Africa, Asia, Nord America, Sud America, Oceania")
world = "World"

for vaccinazioni in zone:
    vaccinazioni_df = es_finale.loc[es_finale["continent"] == vaccinazioni] 
    vaccinazioni_massimo = max(vaccinazioni_df.dropna(subset="total_vaccinations")["total_vaccinations"])
    vaccinazioni_minimo = min(vaccinazioni_df.dropna(subset="total_vaccinations")["total_vaccinations"])
    vaccinazioni_media = np.mean(vaccinazioni_df.dropna(subset="total_vaccinations")["total_vaccinations"])
    """vaccinazioni_df_1= es_finale.loc[es_finale["continent"] == world] 
    vaccinazioni_mondo = max(vaccinazioni_df_1.dropna(subset="total_vaccinations")["total_vaccinations"])
    percentuale_mondo = (vaccinazioni_massimo) / (vaccinazioni_mondo) * 100"""

    print(f"per quanto riguarda le vaccinazioni totali per ogni continente , il max è {vaccinazioni_massimo}, il min è {vaccinazioni_minimo}, la media è {vaccinazioni_media}")
    #print(f"Invece, per quanto riguarda la percentuale di casi totali rispetto al mondo, otteniamo {percentuale_mondo}%")
    print("---------------")
# Out:
# Casi per ogni continente in ordine: Europa, Africa, Asia, Nord America, Sud America, Oceania
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 192221468.0, il min è 0.0, la media è 27277928.563184228
# ---------------
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 133048021.0, il min è 0.0, la media è 8012152.22106591
# ---------------
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 3491077000.0, il min è 0.0, la media è 230631503.40923405
# ---------------
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 676728782.0, il min è 0.0, la media è 64695277.36218239
# ---------------
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 486436436.0, il min è 0.0, la media è 65958353.543699816
# ---------------
# per quanto riguarda le vaccinazioni totali per ogni continente , il max è 69306345.0, il min è 0.0, la media è 12617372.973786408
# ---------------

# %%
#5
"""•Alla fine, basandosi sui calcoli fatti, il committente chiede di stilare
un breve (tre o quattro righe) paragrafo testuale riassuntivo sulle statistiche di casi e vaccinazioni, 
che si concentri solo sulle differenze esistenti tra Europa, Sud America e Oceania"""

"""
Sull'analisi svolta sui dati riguardanti il Covid19, da gennaio 2020 a febbraio 2024, confrontando Europa, Sud America e Oceania,
I casi massimi totali di Covid19, rispettivamente in ordine di grandezza, sono i seguenti:
    -Europa con 38997490 casi ;
    -Sud America con 37519960 casi;
    -Oceania con 11769858 casi.
Per quanto riguarda i casi massimi totali di vaccinazioni, in ordine di grandezza:
    -Sud America con 486436436 vaccinati;
    -Europa con 192221468 vaccinati;
    -Oceania con 69306345 vaccinati;
"""
import matplotlib.pyplot as plt  
# Grafico riepilogativo per casi totali covid19
continenti_confronto = ["Sud America", "Europa", "Oceania"]
dati_confronto = [38997490, 37519960, 11769858]
plt.figure(figsize=(13,6))
plt.barh(continenti_confronto,dati_confronto, color = "red", height=0.5, )
plt.title("Casi totali Covid19", color = "r")
plt.ylabel("Contagi", color = "r")
plt.legend(["casi totali per continente"])
plt.text(38997490,0,"38997490")
plt.text(37519960,1,"37519960")
plt.text(11769858,2,"11769858")
# Out:
# Text(11769858, 2, '11769858')

# %%
#5
# Grafico riepilogativo per vaccinazioni totali
continenti_confronto = ["Sud America", "Europa", "Oceania"]
dati_confronto_vac = [486436436, 192221468, 69306345]

plt.figure(figsize=(13, 6))
plt.barh(continenti_confronto,dati_confronto_vac, color = "green",height=0.5)
plt.title("Vaccinazioni totali Covid19", color = "g")
plt.ylabel("Vaccinazioni", color = "g")
plt.legend(["Vaccinazioni totali per continente"])
plt.text(486436436,0,"486436436")
plt.text(192221468,1,"192221468")
plt.text(69306345,2,"69306345")
# Out:
# Text(69306345, 2, '69306345')
